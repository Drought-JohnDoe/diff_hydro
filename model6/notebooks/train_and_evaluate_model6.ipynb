# %% [markdown]
# # Train And Evaluate Locked Model 6
#
# This notebook calls the packaged Python entrypoints rather than duplicating training or evaluation logic.

# %%
from pathlib import Path
import os, subprocess, sys
repo = Path.cwd().resolve()
os.environ.setdefault('MODEL6_PUBLICATION_DATA_ROOT', '/home/mircore/Desktop/diff_hydro')
print(repo)

# %% [markdown]
# ## 1. Train on a subset
# Choose `32`, `455`, `671`, or `custom`.

# %%
subprocess.run([sys.executable, 'model6/train_model6.py', '--subset', '32', '--epochs', '0', '--run-name', 'notebook_smoke'], check=True)

# %% [markdown]
# ## 2. Evaluate streamflow and external products

# %%
subprocess.run([sys.executable, 'model6/evaluate_model6.py'], check=True)

# %% [markdown]
# ## 3. Rebuild publication figures

# %%
subprocess.run([sys.executable, 'model6/make_figures.py'], check=True)

# %% [markdown]
# ## 4. Run the full Rohini-style replication workflow

# %%
subprocess.run([sys.executable, 'model6/run_rohini_replication_figures.py'], check=True)
